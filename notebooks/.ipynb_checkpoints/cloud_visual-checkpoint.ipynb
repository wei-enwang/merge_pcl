# %%
# %matplotlib
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def plot_cloud(arr_4d):
    # Utility function for plotting a pointcloud
    n, m = arr_4d.shape
    if m == 3:
        arr_4d = np.hstack((arr_4d, np.reshape(['b' for _ in range(n)], (n,1))))
    
    fig = plt.figure()
    fig.suptitle(f"Number of points in this cloud:{n}")
    ax = fig.add_subplot(projection='3d')

    ax.scatter3D(arr_4d[:,0].astype(np.float), 
                 arr_4d[:,1].astype(np.float), 
                 arr_4d[:,2].astype(np.float), 
                 c=arr_4d[:,3], s=0.01)
    plt.show()

# %%
plt.ion()

# %% [markdown]
# Load the pointcloud data...

# %%
data_path = os.path.join(os.getcwd(), "../src/clouds/")

# %%
for file in os.listdir(data_path):
    if file.endswith(".npy"):
        cloud = np.load(os.path.join(data_path, file))
        print(cloud)
        plot_cloud(cloud)
# Out:
# [['0.27' '0.08700000000000001' '0.444' 'y']
#  ['0.273' '0.075' '0.441' 'y']
#  ['0.273' '0.075' '0.444' 'y']
#  ...
#  ['0.41400000000000003' '0.126' '0.447' 'y']
#  ['0.41400000000000003' '0.129' '0.444' 'y']
#  ['0.41400000000000003' '0.132' '0.444' 'y']]
# [['0.15' '0.315' '0.465' 'g']
#  ['0.15' '0.312' '0.507' 'g']
#  ['0.15' '0.318' '0.465' 'g']
#  ...
#  ['0.261' '0.318' '0.501' 'g']
#  ['0.261' '0.318' '0.504' 'g']
#  ['0.261' '0.318' '0.507' 'g']]
# [['0.135' '0.34800000000000003' '0.483' 'm']
#  ['0.135' '0.35100000000000003' '0.483' 'm']
#  ['0.135' '0.354' '0.483' 'm']
#  ...
#  ['0.28500000000000003' '0.339' '0.47700000000000004' 'm']
#  ['0.28500000000000003' '0.339' '0.48' 'm']
#  ['0.28500000000000003' '0.339' '0.483' 'm']]
# [['-0.105' '0.24' '0.486' 'b']
#  ['-0.105' '0.246' '0.486' 'b']
#  ['-0.105' '0.249' '0.486' 'b']
#  ...
#  ['0.024' '0.258' '0.486' 'b']
#  ['0.024' '0.258' '0.489' 'b']
#  ['0.024' '0.258' '0.492' 'b']]
# [['0.165' '0.015' '0.462' 'c']
#  ['0.165' '0.015' '0.465' 'c']
#  ['0.165' '0.018000000000000002' '0.465' 'c']
#  ...
#  ['0.261' '-0.024' '0.465' 'c']
#  ['0.261' '-0.024' '0.468' 'c']
#  ['0.261' '-0.024' '0.47100000000000003' 'c']]
# [['0.20400000000000001' '0.12' '0.489' 'r']
#  ['0.20400000000000001' '0.123' '0.489' 'r']
#  ['0.20400000000000001' '0.126' '0.486' 'r']
#  ...
#  ['0.267' '0.189' '0.47100000000000003' 'r']
#  ['0.267' '0.189' '0.47400000000000003' 'r']
#  ['0.267' '0.189' '0.47700000000000004' 'r']]
# [['-0.105' '0.24' '0.486' 'g']
#  ['-0.105' '0.246' '0.486' 'g']
#  ['-0.105' '0.249' '0.486' 'g']
#  ...
#  ['0.024' '0.258' '0.486' 'g']
#  ['0.024' '0.258' '0.489' 'g']
#  ['0.024' '0.258' '0.492' 'g']]
# [['0.006' '-0.153' '0.492' 'c']
#  ['0.006' '-0.135' '0.453' 'c']
#  ['0.006' '-0.132' '0.447' 'c']
#  ...
#  ['0.099' '-0.228' '0.462' 'c']
#  ['0.10200000000000001' '-0.228' '0.453' 'c']
#  ['0.10200000000000001' '-0.228' '0.456' 'c']]
# [['-0.096' '-0.054' '0.444' 'm']
#  ['-0.096' '-0.051000000000000004' '0.444' 'm']
#  ['-0.096' '-0.048' '0.444' 'm']
#  ...
#  ['0.042' '0.003' '0.447' 'm']
#  ['0.042' '0.006' '0.444' 'm']
#  ['0.042' '0.006' '0.447' 'm']]
# [['0.018000000000000002' '0.12' '0.444' 'r']
#  ['0.018000000000000002' '0.12' '0.447' 'r']
#  ['0.018000000000000002' '0.12' '0.45' 'r']
#  ...
#  ['0.129' '0.129' '0.504' 'r']
#  ['0.129' '0.129' '0.507' 'r']
#  ['0.129' '0.132' '0.501' 'r']]
